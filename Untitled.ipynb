# %%
import pandas as pd
import numpy as np
from scipy.signal import argrelextrema
from collections import defaultdict
import warnings
import time, requests
import matplotlib.pyplot as plt
import matplotlib, json
import threading
from IPython.core.display import display, HTML
display(HTML(""))
# %config InlineBackend.figure_format = 'retina'
import concurrent.futures
import datetime
import telebot
# %matplotlib tk
bot = telebot.TeleBot("5863822927:AAG6A3qpxUFaqHoM3Kp50cTejT1V7beH1pE")
room_id = -833718924
from tqdm import tqdm
import mplfinance as mpf
from datetime import timedelta

matplotlib.rcParams['figure.figsize'] = (8, 5)
def get_data(symbol, lookback):
    all_data = pd.DataFrame()
    for x in range(lookback):
        if x == 0:
            data = requests.get(f"https://fapi.binance.com/fapi/v1/klines?symbol={symbol}&interval=1m&limit=1000")
            data = pd.DataFrame(json.loads(data.text), columns=['Open time','Open','High','Low','Close',\
                                                                'Volume','Close time','Quote asset volume',\
                                                                'Number of trades','Taker buy base asset volume',\
                                                                'Taker buy quote asset volume','Ignore'])
        else:
            start = data['Open time'].min()
            data = requests.get(f"https://fapi.binance.com/fapi/v1/klines?symbol={symbol}&interval=1m&limit=1500&endTime={start}")
            data = pd.DataFrame(json.loads(data.text), columns=['Open time','Open','High','Low','Close',\
                                                                'Volume','Close time','Quote asset volume',\
                                                                'Number of trades','Taker buy base asset volume',\
                                                                'Taker buy quote asset volume','Ignore'])

        data = data.astype({'Open':'float','High':'float','Low':'float','Close':'float'})
        all_data = pd.concat([data, all_data], axis=0)
    all_data.drop(columns=['Volume','Close time','Quote asset volume',\
                           'Number of trades','Taker buy base asset volume',\
                           'Taker buy quote asset volume','Ignore'], inplace=True)
    all_data['Open time'] = pd.to_datetime(all_data['Open time']*1000000)
    all_data = all_data.set_index('Open time') 
    all_data.replace(0, method='bfill', inplace=True)
    
    return all_data
        
def get_stock_data(stocklist, lookback):
    stock_data = {}
    start = time.time()
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        datas = {executor.submit(get_data, stock, lookback): stock for stock in tqdm(stocklist, desc='Getting stock data')}
        
        for future in concurrent.futures.as_completed(datas):
            try:
                symbol = datas[future]
                data = future.result()
                stock_data[symbol] = data
            except Exception as e:
                print('Exception {} {}'.format(stock, e))
    end = time.time()
    print(end - start)
    return stock_data

def resample(stock_data, rate):
    for stock in stock_data:
        stock_data[stock] = stock_data[stock].resample(rate, closed='right', label='right').agg({'Open': 'first',
                                                                                                 'High': 'max',
                                                                                                 'Low': 'min',
                                                                                                 'Close': 'last'}).dropna()
    return stock_data

def get_max_min(prices):

    local_max_idx = argrelextrema(prices['High'].values, np.greater, order=1)[0]
    local_min_idx = argrelextrema(prices['Low'].values, np.less)[0]
    
    local_max_draw = list()
    local_min_draw = list()
    
    for idx, value in enumerate(prices['High']):
        if idx in local_max_idx:
            local_max_draw.append(prices['High'].iloc[idx])
        else:
            local_max_draw.append(np.nan)
            
        if idx in local_min_idx:
            local_min_draw.append(prices['Low'].iloc[idx])
        else:
            local_min_draw.append(np.nan)
            
    return local_max_draw, local_min_draw

# %%
def find_patterns(timeframe, stock, prices, local_max_draw, local_min_draw):  
    if len(prices) > 40:
        prices = prices.iloc[-40:]
        
    length = len(local_max_draw)
    ap = []
    color = ['blue', 'orange', 'red', 'yellow']
    color_idx = 0
    ratio = 0.01
    start = time.time()
    for i in range(length): 
        if local_max_draw[i] is np.nan:
            continue
        for j in range(i+1, length):
            if local_min_draw[j] is np.nan:
                continue
            for k in range(j+1, length):
                if local_max_draw[k] is np.nan:
                    continue
                for l in range(k+1, length):
                    if local_min_draw[l] is np.nan:
                        continue
                    for m in range(l+1, length):
                        if local_max_draw[m] is np.nan:
                            continue
#                         print(i, j, k, l, m)
                        first_high = local_max_draw[i]
                        first_low = local_min_draw[j]
                        second_high = local_max_draw[k]
                        second_low = local_min_draw[l]
                        third_high = local_max_draw[m]
            
        
                        if  (m - i < 20 and first_high > first_low and 
                             second_high > first_high and
                             second_high > second_low and
                             second_high > third_high and
                             third_high > first_low and
                             third_high > second_low and
                            abs(first_high - third_high) <= np.mean([first_high, third_high]) * ratio and
                            abs(first_low - second_low) <= np.mean([first_low, second_low]) * ratio and
                            abs(first_high - second_high) <= abs(first_high - first_low) * (1 + ratio) and
                            abs(first_high - first_low) <= abs(first_high - second_high) * (1 + ratio) and
                            abs(first_high - second_high) >= abs(first_high - first_low) * (1 - ratio) and
                            abs(first_high - first_low) >= abs(first_high - second_high) * (1 - ratio) and
                            m > length - 10):
                                head_shoulder = []
                                head_shoulder_points = []
                                high_points = []
                                low_points = []
                                buy_sell_points = []
                                for idx, value in enumerate(prices['High']):
                                    if idx in [m]:
                                        buy_sell_points.append(prices['High'].iloc[idx])
                                    else:
                                        buy_sell_points.append(np.nan)
                                    if idx in [i, k, m]:
                                        head_shoulder_points.append((list(prices.index)[idx], prices['High'].iloc[idx]))
                                        head_shoulder.append(prices['High'].iloc[idx])
                                        if idx in [i, m]:
                                            high_points.append((list(prices.index)[idx], prices['High'].iloc[idx]))
                                            
                                    elif idx in [j, l]:
                                        head_shoulder.append(prices['Low'].iloc[idx])
                                        head_shoulder_points.append((list(prices.index)[idx], prices['Low'].iloc[idx]))
                                        low_points.append((list(prices.index)[idx], prices['Low'].iloc[idx]))
                                    else:
                                        head_shoulder.append(np.nan)
                                ap = []
#                                 print("M: ", head_shoulder_points)
#                                 print("High: ", high_points)
#                                 print("Low: ", low_points)
                                ap.append(mpf.make_addplot(head_shoulder, type='scatter', marker='o', alpha=.3, markersize=50, color=color[color_idx]),
                                 )
                                ap.append(mpf.make_addplot(buy_sell_points, type='scatter', marker='v', markersize=100, color='r'),
                                 )
#                                 color_idx += 1
#                                 color_idx %= len(color)
#                                 i = m
#                                 j = k = l = m = 0
                                mpf.plot(prices, warn_too_much_data=9999999, 
                                         alines=dict(alines=[head_shoulder_points, high_points, low_points], 
                                                     colors=['b', 'y', 'g']), 
                                         title=f"{stock}_{timeframe}", 
                                         type='candle', 
                                         addplot=ap, 
                                         savefig=f'./head_shoulder/{stock}_{timeframe}_{i}_{j}_{k}_{l}_{m}.png')
#                                 bot.send_photo(room_id, photo=open(f'./head_shoulder/{stock}_{timeframe}_{i}_{j}_{k}_{l}_{m}.png', 'rb'))
    
    end = time.time()
#     print("Time cost: ", end - start)
    

def screener(timeframe, stock_data, plot, results):
    
    start = time.time()
    def yoyo(stock, prices):
        local_max_draw, local_min_draw = get_max_min(prices)
        find_patterns(timeframe, stock, prices, local_max_draw, local_min_draw)
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        datas = {executor.submit(yoyo, stock, stock_data[stock]): stock for stock in stock_data}
        for future in concurrent.futures.as_completed(datas):
            continue
#             print("datas[future]: " , datas[future])
#             print("future.resul: " , future.result())
#                     symbol = datas[future]
#                     data = future.result()
#                     stock_data[symbol] = data
#     for stock in stock_data:
#         prices = stock_data[stock]
#         local_max_draw, local_min_draw = get_max_min(prices)
#         find_patterns(timeframe, stock, prices, local_max_draw, local_min_draw)    
    end = time.time()
    print("Time cost: ", end - start)
    

# '5T' = 5 minutes, '60T' = 1 hour.
print(3)
data = requests.get("https://fapi.binance.com/fapi/v1/exchangeInfo")
print(4)
exchangeInfo = data.json()
print(5)
symbol_list = list()
print(6)
for i in exchangeInfo['symbols']:
    symbol_list.append(i['symbol'])


while True:
    print(2)
    now = datetime.datetime.now()
#     time.sleep(60 - now.second)
    stock_data = get_stock_data(symbol_list, 1)
    for timeframe in ['5T', '15T', '30T', '60T']:
        resampled_stock_data = resample(stock_data, timeframe)
        results = screener(timeframe, resampled_stock_data, plot=True, results=True)
    print(now.minute, " finish")
    time.sleep(60)

# Time cost:  55.82657980918884
# Time cost:  0.8329980373382568
# Time cost:  0.18399953842163086
# Time cost:  0.07499957084655762
# Out:
# 3
# 4
# 5
# 6
# 2
# Getting stock data: 100%|█████████████████████████████████████████████████████████| 195/195 [00:00<00:00, 24376.77it/s]
# 5.668355941772461

# %%
bot.send_message(room_id, "hello")

# while True:
#     now = datetime.datetime.now()
#     time.sleep(datetime.datetime.now().second - 60)
#     stock_data = get_stock_data(stocklist, 100)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     413
# --> 414         self.sock = ssl_wrap_socket(
#     415             sock=conn,
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# D:\ProgramData\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     500         # ctx._wrap_socket()
# --> 501         return self.sslsocket_class._create(
#     502             sock=sock,
#
# D:\ProgramData\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042             except (OSError, ValueError):
#
# D:\ProgramData\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1309                 self.settimeout(None)
# -> 1310             self._sslobj.do_handshake()
#    1311         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# D:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot5863822927:AAG6A3qpxUFaqHoM3Kp50cTejT1V7beH1pE/sendMessage?chat_id=-833718924&text=hello (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29920\702683357.py in <module>
# ----> 1 bot.send_message(room_id, "hello")
#       2
#       3 # while True:
#       4 #     now = datetime.datetime.now()
#       5 #     time.sleep(datetime.datetime.now().second - 60)
#
# D:\ProgramData\Anaconda3\lib\site-packages\telebot\__init__.py in send_message(self, chat_id, text, parse_mode, entities, disable_web_page_preview, disable_notification, protect_content, reply_to_message_id, allow_sending_without_reply, reply_markup, timeout)
#    1547
#    1548         return types.Message.de_json(
# -> 1549             apihelper.send_message(
#    1550                 self.token, chat_id, text, disable_web_page_preview, reply_to_message_id,
#    1551                 reply_markup, parse_mode, disable_notification, timeout,
#
# D:\ProgramData\Anaconda3\lib\site-packages\telebot\apihelper.py in send_message(token, chat_id, text, disable_web_page_preview, reply_to_message_id, reply_markup, parse_mode, disable_notification, timeout, entities, allow_sending_without_reply, protect_content)
#     275     if protect_content is not None:
#     276         payload['protect_content'] = protect_content
# --> 277     return _make_request(token, method_url, params=payload, method='post')
#     278
#     279
#
# D:\ProgramData\Anaconda3\lib\site-packages\telebot\apihelper.py in _make_request(token, method_name, method, params, files)
#     154             timeout=(connect_timeout, read_timeout), proxies=proxy)
#     155     else:
# --> 156         result = _get_req_session().request(
#     157             method, request_url, params=params, files=files,
#     158             timeout=(connect_timeout, read_timeout), proxies=proxy)
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# D:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     561             if isinstance(e.reason, _SSLError):
#     562                 # This branch is for urllib3 v1.22 and later.
# --> 563                 raise SSLError(e, request=request)
#     564
#     565             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot5863822927:AAG6A3qpxUFaqHoM3Kp50cTejT1V7beH1pE/sendMessage?chat_id=-833718924&text=hello (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
